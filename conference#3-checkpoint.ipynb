# %%
import requests
import json

# %%
url = 'https://ct-mock-tech-assessment.herokuapp.com/'
r =requests.get(url)
print('Status code:', r.status_code)
# Out:
# Status code: 200

# %%
resp_dict = r.json()

# %%
print(resp_dict.keys())
# Out:
# dict_keys(['partners'])

# %%
print('Total repositories:', resp_dict['partners'])
# Out:
# Total repositories: [{'availableDates': ['2017-05-19', '2017-05-20', '2017-05-21', '2017-05-26', '2017-05-28', '2017-05-29', '2017-06-01', '2017-06-02', '2017-06-03'], 'country': 'United States', 'email': 'rketring@codingtemple.com', 'firstName': 'Rebbeca', 'lastName': 'Ketring'}, {'availableDates': ['2017-05-25', '2017-05-28', '2017-05-29', '2017-05-30', '2017-05-31', '2017-06-02', '2017-06-03'], 'country': 'United States', 'email': 'ccafaro@codingtemple.com', 'firstName': 'Casey', 'lastName': 'Cafaro'}, {'availableDates': ['2017-05-18', '2017-05-20', '2017-05-21', '2017-05-22', '2017-05-25', '2017-05-26', '2017-05-28', '2017-05-29', '2017-05-31', '2017-06-01', '2017-06-02', '2017-06-03'], 'country': 'United States', 'email': 'mlacau@codingtemple.com', 'firstName': 'Merilyn', 'lastName': 'Lacau'}, {'availableDates': ['2017-05-16', '2017-05-21', '2017-05-28', '2017-05-29', '2017-06-02', '2017-06-03'], 'country': 'United States', 'email': 'eomersa@codingtemple.com', 'firstName': 'Este
# ...

# %%
repo_dicts = resp_dict['partners']
print("Repositories returned:", len(repo_dicts))
# Out:
# Repositories returned: 233

# %%
repo_dict = repo_dicts[0]
print("\nKeys:", len(repo_dict))
for key in sorted(repo_dict.keys()):
    print(key)
# Out:
# Keys: 5
# availableDates
# country
# email
# firstName
# lastName

# %%
print("\nSelected information about first repository:")
print('Dates:', repo_dict['availableDates'])
print('Country:', repo_dict['country'])
print('Email:', repo_dict['email'])
print('f_name:', repo_dict['firstName'])
print('l_name:', repo_dict['lastName'])
# Out:
# Selected information about first repository:
# Dates: ['2017-05-19', '2017-05-20', '2017-05-21', '2017-05-26', '2017-05-28', '2017-05-29', '2017-06-01', '2017-06-02', '2017-06-03']
# Country: United States
# Email: rketring@codingtemple.com
# f_name: Rebbeca
# l_name: Ketring

# %%
print("\nSelected information about each repository:")
for repo_dict in repo_dicts:
    print('Dates:', repo_dict['availableDates'])
    print('Country:', repo_dict['country'])
    print('Email:', repo_dict['email'])
    print('f_name:', repo_dict['firstName'])
    print('l_name:', repo_dict['lastName'])
# Out:
# Selected information about each repository:
# Dates: ['2017-05-19', '2017-05-20', '2017-05-21', '2017-05-26', '2017-05-28', '2017-05-29', '2017-06-01', '2017-06-02', '2017-06-03']
# Country: United States
# Email: rketring@codingtemple.com
# f_name: Rebbeca
# l_name: Ketring
# Dates: ['2017-05-25', '2017-05-28', '2017-05-29', '2017-05-30', '2017-05-31', '2017-06-02', '2017-06-03']
# Country: United States
# Email: ccafaro@codingtemple.com
# f_name: Casey
# l_name: Cafaro
# Dates: ['2017-05-18', '2017-05-20', '2017-05-21', '2017-05-22', '2017-05-25', '2017-05-26', '2017-05-28', '2017-05-29', '2017-05-31', '2017-06-01', '2017-06-02', '2017-06-03']
# Country: United States
# Email: mlacau@codingtemple.com
# f_name: Merilyn
# l_name: Lacau
# Dates: ['2017-05-16', '2017-05-21', '2017-05-28', '2017-05-29', '2017-06-02', '2017-06-03']
# Country: United States
# Email: eomersa@codingtemple.com
# f_name: Ester
# l_name: Omersa
# ...

# %%
r.json()
# Out:
# {'partners': [{'availableDates': ['2017-05-19',
#     '2017-05-20',
#     '2017-05-21',
#     '2017-05-26',
#     '2017-05-28',
#     '2017-05-29',
#     '2017-06-01',
#     '2017-06-02',
#     '2017-06-03'],
#    'country': 'United States',
#    'email': 'rketring@codingtemple.com',
#    'firstName': 'Rebbeca',
#    'lastName': 'Ketring'},
#   {'availableDates': ['2017-05-25',
#     '2017-05-28',
#     '2017-05-29',
#     '2017-05-30',
#     '2017-05-31',
#     '2017-06-02',
#     '2017-06-03'],
#    'country': 'United States',
#    'email': 'ccafaro@codingtemple.com',
#    'firstName': 'Casey',
#    'lastName': 'Cafaro'},
#   {'availableDates': ['2017-05-18',
#     '2017-05-20',
#     '2017-05-21',
#     '2017-05-22',
#     '2017-05-25',
#     '2017-05-26',
#     '2017-05-28',
#     '2017-05-29',
#     '2017-05-31',
#     '2017-06-01',
#     '2017-06-02',
#     '2017-06-03'],
#    'country': 'United States',
#    'email': 'mlacau@codingtemple.com',
#    'firstName': 'Merilyn',
# ...

# %%
class Partners:
    def __init__(self, availableDates, country, email, firstName,lastName):
        self.availableDates = availableDates
        self.country = country
        self.email = email
        self.firstName = firstName
        self.lastName = lastName
    
    def from_dict(self,repo_dicts):
        for field in ['availableDates', 'country', 'email', 'firstNamet', 'lastName']
            if field in data:
                setattr[self,field,data[field]]
# Partners()
# Out:
#   File "<ipython-input-11-cc7e31c765ef>", line 10
#     for field in ['availableDates', 'country', 'email', 'firstNamet', 'lastName']
#                                                                                  ^
# SyntaxError: invalid syntax
