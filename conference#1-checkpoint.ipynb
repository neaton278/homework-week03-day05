# %%
# import json
import requests

page_link = 'https://ct-mock-tech-assessment.herokuapp.com/'

# page = requests.get(page_link)

# %%
page = requests.get(page_link)
page.status_code
# Out:
# 200

# %%
page.text
# Out:
# '{"partners":[{"availableDates":["2017-05-19","2017-05-20","2017-05-21","2017-05-26","2017-05-28","2017-05-29","2017-06-01","2017-06-02","2017-06-03"],"country":"United States","email":"rketring@codingtemple.com","firstName":"Rebbeca","lastName":"Ketring"},{"availableDates":["2017-05-25","2017-05-28","2017-05-29","2017-05-30","2017-05-31","2017-06-02","2017-06-03"],"country":"United States","email":"ccafaro@codingtemple.com","firstName":"Casey","lastName":"Cafaro"},{"availableDates":["2017-05-18","2017-05-20","2017-05-21","2017-05-22","2017-05-25","2017-05-26","2017-05-28","2017-05-29","2017-05-31","2017-06-01","2017-06-02","2017-06-03"],"country":"United States","email":"mlacau@codingtemple.com","firstName":"Merilyn","lastName":"Lacau"},{"availableDates":["2017-05-16","2017-05-21","2017-05-28","2017-05-29","2017-06-02","2017-06-03"],"country":"United States","email":"eomersa@codingtemple.com","firstName":"Ester","lastName":"Omersa"},{"availableDates":["2017-05-18","2017-05-22","2017
# ...

# %%
page.json()
# Out:
# {'partners': [{'availableDates': ['2017-05-19',
#     '2017-05-20',
#     '2017-05-21',
#     '2017-05-26',
#     '2017-05-28',
#     '2017-05-29',
#     '2017-06-01',
#     '2017-06-02',
#     '2017-06-03'],
#    'country': 'United States',
#    'email': 'rketring@codingtemple.com',
#    'firstName': 'Rebbeca',
#    'lastName': 'Ketring'},
#   {'availableDates': ['2017-05-25',
#     '2017-05-28',
#     '2017-05-29',
#     '2017-05-30',
#     '2017-05-31',
#     '2017-06-02',
#     '2017-06-03'],
#    'country': 'United States',
#    'email': 'ccafaro@codingtemple.com',
#    'firstName': 'Casey',
#    'lastName': 'Cafaro'},
#   {'availableDates': ['2017-05-18',
#     '2017-05-20',
#     '2017-05-21',
#     '2017-05-22',
#     '2017-05-25',
#     '2017-05-26',
#     '2017-05-28',
#     '2017-05-29',
#     '2017-05-31',
#     '2017-06-01',
#     '2017-06-02',
#     '2017-06-03'],
#    'country': 'United States',
#    'email': 'mlacau@codingtemple.com',
#    'firstName': 'Merilyn',
# ...

# %%
data = page.json()
partner = data['partners'][0]

# %%
partner = data['partners']

# %%
par = data['partners'][0]
for a in par: 
    print (a)
# Out:
# availableDates
# country
# email
# firstName
# lastName

# %%
for availableDates in partner: 
    print (availableDates)
# Out:
# {'availableDates': ['2017-05-19', '2017-05-20', '2017-05-21', '2017-05-26', '2017-05-28', '2017-05-29', '2017-06-01', '2017-06-02', '2017-06-03'], 'country': 'United States', 'email': 'rketring@codingtemple.com', 'firstName': 'Rebbeca', 'lastName': 'Ketring'}
# {'availableDates': ['2017-05-25', '2017-05-28', '2017-05-29', '2017-05-30', '2017-05-31', '2017-06-02', '2017-06-03'], 'country': 'United States', 'email': 'ccafaro@codingtemple.com', 'firstName': 'Casey', 'lastName': 'Cafaro'}
# {'availableDates': ['2017-05-18', '2017-05-20', '2017-05-21', '2017-05-22', '2017-05-25', '2017-05-26', '2017-05-28', '2017-05-29', '2017-05-31', '2017-06-01', '2017-06-02', '2017-06-03'], 'country': 'United States', 'email': 'mlacau@codingtemple.com', 'firstName': 'Merilyn', 'lastName': 'Lacau'}
# ...

# %%
# drivers = data ['partners'][0] shows only data for the first person

# %%
for available in p: 
    print (available)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-ce35570660ac> in <module>
# ----> 1 for available in p:
#       2     print (available)
#
# NameError: name 'p' is not defined

# %%
for a in partner: 
    print (a)
    new_dict = 
    {
        'date':a['availableDates'],
        'country':a['country'], 
        'mail':a ['email'],
        'f_name':a['firstName'],
        'l_name':a['lastName'],
    }
    print(new_dict)
# Out:
#   File "<ipython-input-50-1ecb92475830>", line 3
#     new_dict =
#                ^
# SyntaxError: invalid syntax

# %%
a.json()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-0c1d3e82273b> in <module>
# ----> 1 a.json()
#
# AttributeError: 'dict' object has no attribute 'json'

# %%
for country in drivers:
    print (country)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-52564afe1126> in <module>
# ----> 1 for country in drivers:
#       2     print (country)
#
# NameError: name 'drivers' is not defined

# %%
# new_dict = {
#     'date':a['availableDates'][],
#     'country':a['country'][], 
#     'mail':a ['email'][],
#     'f_name':a['firstName'][],
#     'l_name':a['lastName'][],
#     }
#     print(new_dict)
